# %% [markdown]
# taller numero 2

# %%
from numpy import array
from numpy import array
from numpy import arange
from pylab import plot, show
from pylab import savefig
from numpy import linspace, sin, cos 
from pylab import ylim, xlim, grid,xlabel,ylabel
from numpy import loadtxt
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# en la grafica  de año vs average se puede obsservar de manera general un comportamiento un poco lineal que muestra que a medida que van aumentando los años o que pasa el tiempo tambien va aumentando el el valor promedio  de producion de co2; y se espera que si no se toman medias de solucion  o contencion,lo que se espera es que siga asi debido a la tendencia a crecer que posee el fenomeno.
# ahora si analizamos mas detenidamente la grafica, se puede ver que aparte de ese comportamiento de forma lineal tambien presenta pequeñass osciaciones que tambien van variando, debido a que en los primeros años la amplitud de la oscilacion es mas pequeña, es decir que el crecimiento de co2 es mas pequeño,mientras que para los años finales la amplitud de las oscilaciones aumenta queriendo dar a entender que para ese entonces el crecimiento en el co2 va a ser mucho mayor,mostarandose asi la tendencia de crecimiento de foma anual como de forma general, lo que lleva a la conclusion de que se debe prestar mucha atencion a este fenomeno y tratar de corregirlo porque si no seguira en aumento, hasta que ya no pueda ser controlado.

# %%
from numpy import loadtxt
from numpy import array
from pylab import plot, show
import numpy as np
from pylab import ylim, xlim, grid,xlabel,ylabel
import scipy as sc
import matplotlib.pyplot as plt
dataco2= loadtxt("co2_mm_gl.txt",float)
X=array(dataco2[:,2])
Y=array(dataco2[:,3])
X=array([np.ones(470),X]).T
B=np.linalg.inv(X.T @ X) @ X.T @ Y
plot([1980,2019],[B[0]+B[1]*1980,B[0]+B[1]*2019],c="green")
plot(dataco2[:,2], dataco2[:,3])
xlabel("año")
ylabel("promedio")

plt.show()

# %%
dataco2= loadtxt("co2_mm_gl.txt",float)
plot(dataco2[:,2], dataco2[:,3],c="magenta")
X1=array(dataco2[0:235,2])
Y1=array(dataco2[0:235,3])
X1=array([np.ones(235),X1]).T
B1=np.linalg.inv(X1.T @ X1) @ X1.T @ Y1
plot([1980,2000],[B1[0]+B1[1]*1980,B1[0]+B1[1]*2000],c="orange")
xlim(1980.,2000)
ylim(336,370)
xlabel("año")
ylabel("promedio")
show()

# %%
dataco2= loadtxt("co2_mm_gl.txt",float)
plot(dataco2[:,2], dataco2[:,3])
X2=array(dataco2[235:470,2])
Y2=array(dataco2[235:470,3])
X2=array([np.ones(235),X2]).T
B2=np.linalg.inv(X2.T @ X2) @ X2.T @ Y2
plot([2000,2019],[B2[0]+B2[1]*2000,B2[0]+B2[1]*2019],c="red")
xlim(2000.,2020)
ylim(365,415)
xlabel("año")
ylabel("promedio")
show()
